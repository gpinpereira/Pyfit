# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

from Fitter import Fitter
from Fitter import Functions
import numpy as np
import matplotlib.pyplot as plt
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
f = Fitter("linear")

# %%
m, b = 1,0
xx = np.arange(10,100,0.01)
yy = xx*m+b + np.random.normal(5, 2, size = xx.shape)

f.fit(xx,yy)
m,b = f.getParams()
print(m,b)
fig = plt.figure()
plt.scatter(xx, yy,s=0.5)

plt.plot(xx, xx*m+b, c="orange")
# Out:
# 1.001116528535935 4.963650122017645
# <img src="data:image/png;base64,..." width="639.999974568686">
